# %%
import pandas

from matplotlib import pyplot

# %matplotlib inline

# %% [markdown]
# ## Esempio di dati tabulati

# %%
# esempio di tabella da inserire in HTML nella relazione

# %%
dataframe = pandas.read_csv("../data/cell_towers_diff-2016012100.csv")
troncato = dataframe[0:10]
troncato
# Out:
#   radio  mcc  net   area   cell  unit        lon        lat   range  samples  \
# 0   GSM  262    7  20205   2227   NaN  13.308816  52.512122  147481    14586
# 1   GSM  262    2    685   6132   NaN   7.018766  49.223543   14976     5336
# 2   GSM  262    1  14660  39399   NaN   9.879624  51.335388  101430     4049
# 3   GSM  262    7  20202  33063   NaN  13.327494  52.516999  148854     6412
# 4   GSM  262    7  20205   2472   NaN  13.296922  52.507817  132401    11216
# 5   GSM  262    7  20205  22279   NaN  13.301944  52.493130  140387    41416
# 6   GSM  262    2    323   2063   NaN  13.234158  52.637024  107054    27672
# 7   GSM  262    2    323  59151   NaN  13.226567  52.611433  133482     9368
# 8   GSM  262    2    321  10522   NaN  13.291904  52.532979  123204    79763
# 9   GSM  262    2    323  33722   NaN  13.271971  52.532267   97866    92087
#
#    changeable     created     updated  averageSignal
# 0           1  1299573448  1453335612            -64
# 1           1  1299584114  1453337312            -74
# 2           1  1299693112  1453335486            -57
# 3           1  1301668631  1453335612            -61
# 4           1  1301668631  1453335612            -65
# 5           1  1301759017  1453335742            -63
# 6           1  1302844384  1453337701            -55
# 7           1  1302844384  1453336789            -85
# 8           1  1302845958  1453336130            -58
# 9           1  1302845958  1453336130            -60

# %%
with open('../doc/dataframe_troncato.html', 'w') as tabella:
    tabella.write(troncato.to_html(index=False))

# %%
TODO svuotare il notebook Fede e mettere qua la roba del data selection

# %% [markdown]
# # Scatterplot preliminare non georeferenziato

# %%
roma = pandas.read_csv("../data/Roma_towers.csv")

roma.plot(kind='scatter',
          x='lon',
          y='lat',
          marker='.',
          color='#3333ff',
          label='Roma towers',
          #xlim=(12.34, 12.64),
          #ylim=(41.74,42.04),
          figsize=(10,10))

# pyplot.show()

# TODO mettere il grafico quadrato e con le scale uguali
# e con le coordinate del colosseo al centro

# TODO mettere output del comando in SVG
# TODO mettere interattività, magari utilizzando Bokeh o mpld3

# vedere
# http://stackoverflow.com/questions/24525111/how-can-i-get-the-output-of-a-matplotlib-plot-as-an-svg
# https://nickcharlton.net/posts/outputting-matplotlib-plots.html

pyplot.xlabel('Longitudine')
pyplot.ylabel('Latitudine')
pyplot.legend(loc='best', frameon=False)
pyplot.savefig('../img/map/Roma_non_georeferenziata.svg', format='svg', dpi=600, transparent=True)

# %%
import math
import itertools

xcentro = 41.891969
ycentro = 12.495644
longitudini = [41.914456, 41.990672, 41.793883, 41.812566, 41.956277]
latitudini = [12.615807, 12.502714, 12.511297, 12.396628, 12.384611]
distanza = []

for (x,y) in zip(longitudini,latitudini):
    raggio = math.sqrt((xcentro-x)**2+(ycentro-y)**2)
    distanza.append(raggio)

media = 0
for i in distanza:
	media += i
media /= len(distanza)

print media
# Out:
# 0.115152953461

# %%
def distanza(x, y)
    d = math.sqrt((x-xcentro)**2+(y-ycentro)**2)
    return d

map(distanza, x, y)

filter(d < raggio, x, y)

# %% [markdown]
# TODO:
# Prendere arrays coordinate, fare array distanze, mettere colonna distanze in dataframe, selezionare righe con variabile compresa entro raggiomedio, ggwpbb

# %%
import pandas

# %%
dataframe = pandas.read_csv("cell_towers_diff-2016012100.csv")

# %%
dataframe['lon'] == "Noise - Street/Sidewalk"
coordinate = dataframe[['lon', 'lat']]
coordinate
# Out:
#              lon        lat
# 0      13.308816  52.512122
# 1       7.018766  49.223543
# 2       9.879624  51.335388
# 3      13.327494  52.516999
# 4      13.296922  52.507817
# 5      13.301944  52.493130
# 6      13.234158  52.637024
# 7      13.226567  52.611433
# 8      13.291904  52.532979
# 9      13.271971  52.532267
# 10     13.283409  52.531607
# 11     12.829914  52.596090
# 12     13.287963  52.529251
# 13     12.915401  52.709182
# 14     12.935781  52.688761
# 15     12.544687  53.048044
# 16     12.530230  53.115050
# 17     12.560712  53.033344
# 18     10.343923  53.563760
# 19     10.281063  53.564034
# 20      9.475669  53.583495
# 21     13.390942  52.468670
# 22     10.129178  51.880600
# 23     12.573997  52.739037
# 24     12.585801  52.767839
# 25     12.424859  52.762889
# 26      9.914099  51.619839
# 27      9.898916  51.555754
# 28      9.906995  51.596403
# 29      9.868946  51.476316
# ...          ...        ...
# 4284  106.944634  -6.269359
# ...
